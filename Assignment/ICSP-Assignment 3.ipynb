# %% [markdown]
# # INTRODUCTION TO COMPUTER SCIENCE WITH PYTHON
# ## ASSIGNMENT 3

# %% [markdown]
# # Exercise 1: Convert Celsius to Fahrenheit
# ## Write a function that takes a temperature in Celsius and returns the equivalent temperature in Fahrenheit.

# %% [markdown]
# # Exercise 2: Calculate the Perimeter of a Rectangle
# ## Create a function that calculates the perimeter of a rectangle, given its length and width.

# %% [markdown]
# # Exercise 3: Count the Number of Words in a Sentence
# ## Write a function that takes a string (a sentence) and returns the number of words in it.

# %% [markdown]
# # Exercise 4: Multiply Two Numbers
# ## Create a function that multiplies two numbers and returns the result.

# %% [markdown]
# # Exercise 5: Concatenate Strings
# ## Write a function that takes two strings and concatenates (joins) them into one.

# %% [markdown]
# ## Let's try to plot a function $f: \mathbb{R} \rightarrow \mathbb{R}$

# %% [markdown]
# ## Run the following cell
# This is a convenience function for the moment. Just run this cell even if you don't know what it does
# # DO NOT MODIFY - JUST RUN

# %%
# This is a convenience function for the moment. Just run this cell even if you don't know what it does
# DO NOT MODIFY 
import numpy as np  # For numerical operations and creating arrays
import matplotlib.pyplot as plt  # For plotting

def plot_function(func, x_range, num_points=500):
    """
    Plots the given mathematical function.

    Parameters:
    - func: The function to plot, defined by the user.
    - x_range: A tuple specifying the range of x values (min, max).
    - num_points: The number of points to plot within the x_range (default is 500).
    """
    # Generate an array of x values over the specified range
    x = np.linspace(x_range[0], x_range[1], num_points)

    # Calculate corresponding y values by applying the user-defined function
    y = func(x)

    # Plot the function
    plt.plot(x, y, label=f'f(x) = {func.__name__}', color='blue')

    # Add labels and title
    plt.xlabel('x')
    plt.ylabel('f(x)')
    plt.title(f'Plot of f(x) = {func.__name__}')

    # Add a grid and legend
    plt.grid(True)
    plt.legend()

    # Show the plot
    plt.show()

# %% [markdown]
# ## Now try to plot a function
# Run the below cell to plot the function $y = x^2 -2 x$
# Change the function at your pleasure to plot different functions

# %%
# for sqrt(x) use np.sqrt(x)
# for sin(x) use np.sin(x)
def my_function(x):
    
    # ----CHANGE HERE
    # IF YOU WANT TO CHANGE THE FUNCTION UNCOMMENT A LINE 
    
    f = x**2-2*x        # Define here the function to plot
    
    # UNCOMMENT BELOW HERE to change function 
    # f = np.sin(x)
    # f = np.cos(x)*x
    # f = (1-x**2)/np.sqrt(1+x**2)
    return f  

# these are domain endpoints
left_endpoint = -10
righ_endpoint = +10 

# Example usage: plot the user-defined function
plot_function(my_function, (left_endpoint, righ_endpoint))
